# %%
import numpy as np
import scipy.io
import cebra
from scipy import stats
import matplotlib.pyplot as plt
import sys

# %%
# Load data
file_path = '/Users/devenshidfar/Desktop/Masters/control_recal/data_control_recal/dataverse_files/data/NN_opticflow_dataset.mat'
data = scipy.io.loadmat(file_path, squeeze_me=True, struct_as_record=False)
expt = data['expt']

print(expt.shape)

print(f"Experiment data type: {expt.dtype}")
print(f"Experiment data shape: {expt.shape}")
# Out:
# (65,)
# Experiment data type: object
# Experiment data shape: (65,)

# %%
control_count = 0

for session_idx, session in enumerate(expt):

    control_count += 1

    if control_count <= 10:
        print(f"Skipping session {session_idx + 1}")
        continue 
    elif control_count >= 18:
        break
        


    print(f"Processing session {session_idx + 1}/{len(expt)}")
    print(f"Rat: {session.rat}, Day: {session.day}, Epoch: {session.epoch}")

    # Prepare data
    ros_data = session.rosdata
    start_time = ros_data.startTs
    end_time = ros_data.stopTs
    bin_size = 0.025  # in seconds

    angle = ros_data.encAngle
    angle_times = ros_data.encTimes

    all_spikes = []
    num = 0
    for cluster in session.clust:
        try:
            spike_times = cluster.ts - start_time  # subtraction in microseconds
            print(f"Processing cluster: {cluster.name}")
            print(f"Number of spikes: {len(spike_times)}")
            
            # Bin spikes
            spike_times_sec = spike_times / 1e6
            start_time_sec = 0
            end_time_sec = (end_time - start_time) / 1e6
            
            if len(spike_times_sec) == 0:
                print("Warning: Empty spike_times array")
                continue  # Skip this cluster

            spike_times_sec = spike_times_sec[np.isfinite(spike_times_sec)]
            spike_times_sec = spike_times_sec[(spike_times_sec >= start_time_sec) & (spike_times_sec <= end_time_sec)]

            bins = np.arange(start_time_sec, end_time_sec + bin_size, bin_size)
            #print(f"bins: {bins[:5]}")

            binned_spikes, _, _ = stats.binned_statistic(
                spike_times_sec, 
                np.ones_like(spike_times_sec), 
                statistic='sum', 
                bins=bins
            )

            all_spikes.append(binned_spikes)
            #print(binned_spikes[20:35])
            print(f"Binned spikes shape: {binned_spikes.shape}")

        except Exception as cluster_error:
            print(f"Error processing cluster {cluster.name}: {str(cluster_error)}")
            continue

    print(f"Number of processed clusters: {len(all_spikes)}")

    if not all_spikes:
        print("No valid spike data found")
        continue

    print(f"all spikes shape {len(all_spikes)}")

    neural_data = np.array(all_spikes).T
    neural_times = np.arange(0, (end_time - start_time) / 1e6, bin_size)
    interp_angle = np.interp(neural_times, (angle_times - start_time) / 1e6, angle)

    print(f"Neural data shape: {neural_data.shape}")


    if not all_spikes:
        print("No valid spike data found")
        continue

    print(f"Neural data shape: {neural_data.shape}")

    # neural_data = np.random.normal(loc=1, scale=0.5, size=(1000, 100))
    # neural_data = np.maximum(neural_data, 0)

    # Apply CEBRA
    print(f"Input neural data shape: {neural_data.shape}")
    model = cebra.CEBRA(output_dimension=2, max_iterations=1000, batch_size=128)
    model.fit(neural_data)
    embeddings = model.transform(neural_data)
    print(f"Output embeddings shape: {embeddings.shape}")

    #model_shuffled = cebra.CEBRA(output_dimension=2, batch_size=128)
    #model_shuffled.fit(np.random.permutation(neural_data))
    #shuffled_embeddings = model_shuffled.transform(neural_data)
     # Visualize results
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(embeddings[:, 0], embeddings[:, 1])
    plt.title(f"Rat {session.rat}, Day {session.day}, Epoch {session.epoch} Embeddings")
    plt.xlabel('Embedding Dimension 1')
    plt.ylabel('Embedding Dimension 2')
    plt.show()

    # Optional: Save embeddings
    np.save(f'/Users/devenshidfar/Desktop/Masters/NRSC_510B/cebra_control_recal/angle_embeddings_discovery/embeddings_rat{session.rat}_day{session.day}_epoch{session.epoch}.npy', embeddings)

    # Break after the first session for debugging
    #break
# Out:
# Skipping session 1
# Skipping session 2
# Skipping session 3
# Skipping session 4
# Skipping session 5
# Skipping session 6
# Skipping session 7
# Skipping session 8
# Skipping session 9
# Skipping session 10
# Processing session 11/65
# Rat: 791, Day: 7, Epoch: m1
# Processing cluster: TT10/cl-maze1.1
# Number of spikes: 916
# Binned spikes shape: (55211,)
# Processing cluster: TT10/cl-maze1.2
# Number of spikes: 2256
# Binned spikes shape: (55211,)
# Processing cluster: TT10/cl-maze1.3
# Number of spikes: 448
# Binned spikes shape: (55211,)
# Processing cluster: TT10/cl-maze1.8
# Number of spikes: 1276
# Binned spikes shape: (55211,)
# Processing cluster: TT11/cl-maze1.1
# Number of spikes: 251
# Binned spikes shape: (55211,)
# Processing cluster: TT13/cl-maze1.1
# Number of spikes: 7119
# Binned spikes shape: (55211,)
# Processing cluster: TT13/cl-maze1.2
# Number of spikes: 4328
# Binned spikes shape: (55211,)
# Processing cluster: TT13/cl-maze1.3
# Number of spikes: 940
# Binned spikes shape: (55211,)
# Processing cluster: TT15/cl-maze1.1
# Number of spikes: 398
# Binned spikes shape: (55211,)
# Processing cluster: TT15/cl-maze1.2
# Number of spikes: 657
# Binned spikes shape: (55211,)
# Processing cluster: TT15/cl-maze1.3
# Number of spikes: 2927
# Binned spikes shape: (55211,)
# Processing cluster: TT15/cl-maze1.4
# Number of spikes: 3817
# Binned spikes shape: (55211,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 5060
# Binned spikes shape: (55211,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 3817
# Binned spikes shape: (55211,)
# Processing cluster: TT5/cl-maze1.3
# Number of spikes: 6660
# Binned spikes shape: (55211,)
# Processing cluster: TT5/cl-maze1.4
# Number of spikes: 9357
# Binned spikes shape: (55211,)
# Processing cluster: TT5/cl-maze1.5
# Number of spikes: 4858
# Binned spikes shape: (55211,)
# Processing cluster: TT6/cl-maze1.1
# Number of spikes: 2676
# Binned spikes shape: (55211,)
# Processing cluster: TT6/cl-maze1.2
# Number of spikes: 2166
# Binned spikes shape: (55211,)
# Processing cluster: TT6/cl-maze1.4
# Number of spikes: 140
# Binned spikes shape: (55211,)
# Processing cluster: TT6/cl-maze1.5
# Number of spikes: 8904
# Binned spikes shape: (55211,)
# Processing cluster: TT8/cl-maze1.1
# Number of spikes: 36521
# Binned spikes shape: (55211,)
# Processing cluster: TT8/cl-maze1.2
# Number of spikes: 12344
# Binned spikes shape: (55211,)
# Processing cluster: TT8/cl-maze1.3
# Number of spikes: 373
# Binned spikes shape: (55211,)
# Processing cluster: TT8/cl-maze1.5
# Number of spikes: 868
# Binned spikes shape: (55211,)
# Number of processed clusters: 25
# all spikes shape 25
# Neural data shape: (55211, 25)
# Neural data shape: (55211, 25)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
# Processing session 12/65
# Rat: 791, Day: 8, Epoch: m1
# Processing cluster: TT10/cl-maze1.1
# Number of spikes: 387
# Binned spikes shape: (65337,)
# Processing cluster: TT10/cl-maze1.2
# Number of spikes: 2926
# Binned spikes shape: (65337,)
# Processing cluster: TT10/cl-maze1.3
# Number of spikes: 1018
# Binned spikes shape: (65337,)
# Processing cluster: TT10/cl-maze1.4
# Number of spikes: 1400
# Binned spikes shape: (65337,)
# Processing cluster: TT11/cl-maze1.1
# Number of spikes: 83
# Binned spikes shape: (65337,)
# Processing cluster: TT13/cl-maze1.1
# Number of spikes: 4874
# Binned spikes shape: (65337,)
# Processing cluster: TT13/cl-maze1.2
# Number of spikes: 2055
# Binned spikes shape: (65337,)
# Processing cluster: TT14/cl-maze1.1
# Number of spikes: 65
# Binned spikes shape: (65337,)
# Processing cluster: TT14/cl-maze1.2
# Number of spikes: 58
# Binned spikes shape: (65337,)
# Processing cluster: TT15/cl-maze1.1
# Number of spikes: 4769
# Binned spikes shape: (65337,)
# Processing cluster: TT15/cl-maze1.2
# Number of spikes: 6627
# Binned spikes shape: (65337,)
# Processing cluster: TT15/cl-maze1.3
# Number of spikes: 947
# Binned spikes shape: (65337,)
# Processing cluster: TT15/cl-maze1.4
# Number of spikes: 471
# Binned spikes shape: (65337,)
# Processing cluster: TT15/cl-maze1.5
# Number of spikes: 3143
# Binned spikes shape: (65337,)
# Processing cluster: TT16/cl-maze1.1
# Number of spikes: 8630
# Binned spikes shape: (65337,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 6468
# Binned spikes shape: (65337,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 11749
# Binned spikes shape: (65337,)
# Processing cluster: TT5/cl-maze1.3
# Number of spikes: 6659
# Binned spikes shape: (65337,)
# Processing cluster: TT5/cl-maze1.4
# Number of spikes: 5044
# Binned spikes shape: (65337,)
# Processing cluster: TT6/cl-maze1.1
# Number of spikes: 3821
# Binned spikes shape: (65337,)
# Processing cluster: TT6/cl-maze1.2
# Number of spikes: 546
# Binned spikes shape: (65337,)
# Processing cluster: TT8/cl-maze1.1
# Number of spikes: 105
# Binned spikes shape: (65337,)
# Processing cluster: TT8/cl-maze1.2
# Number of spikes: 467
# Binned spikes shape: (65337,)
# Processing cluster: TT8/cl-maze1.3
# Number of spikes: 26419
# Binned spikes shape: (65337,)
# Processing cluster: TT8/cl-maze1.4
# Number of spikes: 42440
# Binned spikes shape: (65337,)
# Processing cluster: TT8/cl-maze1.6
# Number of spikes: 6391
# Binned spikes shape: (65337,)
# Processing cluster: TT8/cl-maze1.7
# Number of spikes: 4289
# Binned spikes shape: (65337,)
# Number of processed clusters: 27
# all spikes shape 27
# Neural data shape: (65337, 27)
# Neural data shape: (65337, 27)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
# Processing session 13/65
# Rat: 791, Day: 9, Epoch: m1
# Processing cluster: TT10/cl-maze1.1
# Number of spikes: 2156
# Binned spikes shape: (65500,)
# Processing cluster: TT10/cl-maze1.2
# Number of spikes: 51
# Binned spikes shape: (65500,)
# Processing cluster: TT10/cl-maze1.3
# Number of spikes: 2484
# Binned spikes shape: (65500,)
# Processing cluster: TT10/cl-maze1.4
# Number of spikes: 18873
# Binned spikes shape: (65500,)
# Processing cluster: TT10/cl-maze1.6
# Number of spikes: 965
# Binned spikes shape: (65500,)
# Processing cluster: TT13/cl-maze1.1
# Number of spikes: 2032
# Binned spikes shape: (65500,)
# Processing cluster: TT14/cl-maze1.2
# Number of spikes: 1245
# Binned spikes shape: (65500,)
# Processing cluster: TT14/cl-maze1.3
# Number of spikes: 820
# Binned spikes shape: (65500,)
# Processing cluster: TT15/cl-maze1.1
# Number of spikes: 1737
# Binned spikes shape: (65500,)
# Processing cluster: TT15/cl-maze1.4
# Number of spikes: 514
# Binned spikes shape: (65500,)
# Processing cluster: TT16/cl-maze1.1
# Number of spikes: 5190
# Binned spikes shape: (65500,)
# Processing cluster: TT4/cl-maze1.1
# Number of spikes: 929
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 4223
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 7855
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.3
# Number of spikes: 7940
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.4
# Number of spikes: 6240
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.5
# Number of spikes: 8917
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.6
# Number of spikes: 118
# Binned spikes shape: (65500,)
# Processing cluster: TT5/cl-maze1.7
# Number of spikes: 5467
# Binned spikes shape: (65500,)
# Processing cluster: TT6/cl-maze1.2
# Number of spikes: 2528
# Binned spikes shape: (65500,)
# Processing cluster: TT6/cl-maze1.3
# Number of spikes: 342
# Binned spikes shape: (65500,)
# Processing cluster: TT6/cl-maze1.4
# Number of spikes: 2787
# Binned spikes shape: (65500,)
# Processing cluster: TT8/cl-maze1.1
# Number of spikes: 44528
# Binned spikes shape: (65500,)
# Processing cluster: TT8/cl-maze1.2
# Number of spikes: 4286
# Binned spikes shape: (65500,)
# Processing cluster: TT9/cl-maze1.1
# Number of spikes: 18133
# Binned spikes shape: (65500,)
# Processing cluster: TT9/cl-maze1.2
# Number of spikes: 17672
# Binned spikes shape: (65500,)
# Processing cluster: TT9/cl-maze1.4
# Number of spikes: 6959
# Binned spikes shape: (65500,)
# Number of processed clusters: 27
# all spikes shape 27
# Neural data shape: (65500, 27)
# Neural data shape: (65500, 27)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
# Processing session 14/65
# Rat: 791, Day: 11, Epoch: m1
# Processing cluster: TT10/cl-maze1.2
# Number of spikes: 2134
# Binned spikes shape: (86267,)
# Processing cluster: TT11/cl-maze1.3
# Number of spikes: 323
# Binned spikes shape: (86267,)
# Processing cluster: TT11/cl-maze1.6
# Number of spikes: 515
# Binned spikes shape: (86267,)
# Processing cluster: TT11/cl-maze1.7
# Number of spikes: 2417
# Binned spikes shape: (86267,)
# Processing cluster: TT11/cl-maze1.8
# Number of spikes: 1098
# Binned spikes shape: (86267,)
# Processing cluster: TT14/cl-maze1.1
# Number of spikes: 653
# Binned spikes shape: (86267,)
# Processing cluster: TT14/cl-maze1.3
# Number of spikes: 59
# Binned spikes shape: (86267,)
# Processing cluster: TT14/cl-maze1.4
# Number of spikes: 92
# Binned spikes shape: (86267,)
# Processing cluster: TT14/cl-maze1.5
# Number of spikes: 6180
# Binned spikes shape: (86267,)
# Processing cluster: TT14/cl-maze1.6
# Number of spikes: 2916
# Binned spikes shape: (86267,)
# Processing cluster: TT15/cl-maze1.1
# Number of spikes: 7630
# Binned spikes shape: (86267,)
# Processing cluster: TT15/cl-maze1.2
# Number of spikes: 297
# Binned spikes shape: (86267,)
# Processing cluster: TT15/cl-maze1.3
# Number of spikes: 1629
# Binned spikes shape: (86267,)
# Processing cluster: TT16/cl-maze1.1
# Number of spikes: 8192
# Binned spikes shape: (86267,)
# Processing cluster: TT3/cl-maze1.1
# Number of spikes: 4971
# Binned spikes shape: (86267,)
# Processing cluster: TT3/cl-maze1.2
# Number of spikes: 1608
# Binned spikes shape: (86267,)
# Processing cluster: TT3/cl-maze1.3
# Number of spikes: 15915
# Binned spikes shape: (86267,)
# Processing cluster: TT3/cl-maze1.5
# Number of spikes: 1517
# Binned spikes shape: (86267,)
# Processing cluster: TT4/cl-maze1.1
# Number of spikes: 251
# Binned spikes shape: (86267,)
# Processing cluster: TT4/cl-maze1.2
# Number of spikes: 697
# Binned spikes shape: (86267,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 12347
# Binned spikes shape: (86267,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 23563
# Binned spikes shape: (86267,)
# Processing cluster: TT5/cl-maze1.3
# Number of spikes: 4133
# Binned spikes shape: (86267,)
# Processing cluster: TT5/cl-maze1.5
# Number of spikes: 25396
# Binned spikes shape: (86267,)
# Processing cluster: TT6/cl-maze1.1
# Number of spikes: 119
# Binned spikes shape: (86267,)
# Processing cluster: TT6/cl-maze1.2
# Number of spikes: 2198
# Binned spikes shape: (86267,)
# Processing cluster: TT6/cl-maze1.3
# Number of spikes: 2658
# Binned spikes shape: (86267,)
# Processing cluster: TT6/cl-maze1.4
# Number of spikes: 4843
# Binned spikes shape: (86267,)
# Processing cluster: TT6/cl-maze1.5
# Number of spikes: 1217
# Binned spikes shape: (86267,)
# Processing cluster: TT6/cl-maze1.7
# Number of spikes: 1245
# Binned spikes shape: (86267,)
# Processing cluster: TT7/cl-maze1.1
# Number of spikes: 11274
# Binned spikes shape: (86267,)
# Processing cluster: TT8/cl-maze1.1
# Number of spikes: 661
# Binned spikes shape: (86267,)
# Processing cluster: TT8/cl-maze1.2
# Number of spikes: 47650
# Binned spikes shape: (86267,)
# Processing cluster: TT8/cl-maze1.3
# Number of spikes: 397
# Binned spikes shape: (86267,)
# Processing cluster: TT8/cl-maze1.4
# Number of spikes: 7625
# Binned spikes shape: (86267,)
# Processing cluster: TT9/cl-maze1.1
# Number of spikes: 9494
# Binned spikes shape: (86267,)
# Processing cluster: TT9/cl-maze1.2
# Number of spikes: 20011
# Binned spikes shape: (86267,)
# Processing cluster: TT9/cl-maze1.3
# Number of spikes: 28118
# Binned spikes shape: (86267,)
# Number of processed clusters: 38
# all spikes shape 38
# Neural data shape: (86267, 38)
# Neural data shape: (86267, 38)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
# Processing session 15/65
# Rat: 791, Day: 12, Epoch: m1
# Processing cluster: TT10/cl-maze1.1
# Number of spikes: 1325
# Binned spikes shape: (70329,)
# Processing cluster: TT10/cl-maze1.2
# Number of spikes: 1710
# Binned spikes shape: (70329,)
# Processing cluster: TT10/cl-maze1.4
# Number of spikes: 125
# Binned spikes shape: (70329,)
# Processing cluster: TT11/cl-maze1.1
# Number of spikes: 2106
# Binned spikes shape: (70329,)
# Processing cluster: TT11/cl-maze1.2
# Number of spikes: 146
# Binned spikes shape: (70329,)
# Processing cluster: TT11/cl-maze1.3
# Number of spikes: 33379
# Binned spikes shape: (70329,)
# Processing cluster: TT11/cl-maze1.4
# Number of spikes: 1865
# Binned spikes shape: (70329,)
# Processing cluster: TT11/cl-maze1.5
# Number of spikes: 1171
# Binned spikes shape: (70329,)
# Processing cluster: TT11/cl-maze1.6
# Number of spikes: 192
# Binned spikes shape: (70329,)
# Processing cluster: TT14/cl-maze1.1
# Number of spikes: 183
# Binned spikes shape: (70329,)
# Processing cluster: TT14/cl-maze1.3
# Number of spikes: 55
# Binned spikes shape: (70329,)
# Processing cluster: TT14/cl-maze1.6
# Number of spikes: 6065
# Binned spikes shape: (70329,)
# Processing cluster: TT14/cl-maze1.7
# Number of spikes: 249
# Binned spikes shape: (70329,)
# Processing cluster: TT14/cl-maze1.9
# Number of spikes: 2896
# Binned spikes shape: (70329,)
# Processing cluster: TT15/cl-maze1.2
# Number of spikes: 77
# Binned spikes shape: (70329,)
# Processing cluster: TT15/cl-maze1.3
# Number of spikes: 455
# Binned spikes shape: (70329,)
# Processing cluster: TT15/cl-maze1.4
# Number of spikes: 4054
# Binned spikes shape: (70329,)
# Processing cluster: TT15/cl-maze1.5
# Number of spikes: 1354
# Binned spikes shape: (70329,)
# Processing cluster: TT16/cl-maze1.1
# Number of spikes: 4170
# Binned spikes shape: (70329,)
# Processing cluster: TT2/cl-maze1.1
# Number of spikes: 4906
# Binned spikes shape: (70329,)
# Processing cluster: TT3/cl-maze1.1
# Number of spikes: 2022
# Binned spikes shape: (70329,)
# Processing cluster: TT3/cl-maze1.2
# Number of spikes: 10493
# Binned spikes shape: (70329,)
# Processing cluster: TT4/cl-maze1.1
# Number of spikes: 180
# Binned spikes shape: (70329,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 3545
# Binned spikes shape: (70329,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 4511
# Binned spikes shape: (70329,)
# Processing cluster: TT6/cl-maze1.1
# Number of spikes: 12069
# Binned spikes shape: (70329,)
# Processing cluster: TT6/cl-maze1.3
# Number of spikes: 1443
# Binned spikes shape: (70329,)
# Processing cluster: TT8/cl-maze1.1
# Number of spikes: 101
# Binned spikes shape: (70329,)
# Processing cluster: TT8/cl-maze1.2
# Number of spikes: 27500
# Binned spikes shape: (70329,)
# Processing cluster: TT8/cl-maze1.3
# Number of spikes: 3019
# Binned spikes shape: (70329,)
# Processing cluster: TT9/cl-maze1.1
# Number of spikes: 2230
# Binned spikes shape: (70329,)
# Processing cluster: TT9/cl-maze1.2
# Number of spikes: 353
# Binned spikes shape: (70329,)
# Number of processed clusters: 32
# all spikes shape 32
# Neural data shape: (70329, 32)
# Neural data shape: (70329, 32)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
# Processing session 16/65
# Rat: 791, Day: 13, Epoch: m1
# Processing cluster: TT14/cl-maze1.12
# Number of spikes: 895
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.13
# Number of spikes: 86
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.3
# Number of spikes: 404
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.5
# Number of spikes: 3146
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.6
# Number of spikes: 160
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.7
# Number of spikes: 205
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.8
# Number of spikes: 758
# Binned spikes shape: (55545,)
# Processing cluster: TT14/cl-maze1.9
# Number of spikes: 1724
# Binned spikes shape: (55545,)
# Processing cluster: TT15/cl-maze1.2
# Number of spikes: 80
# Binned spikes shape: (55545,)
# Processing cluster: TT15/cl-maze1.3
# Number of spikes: 266
# Binned spikes shape: (55545,)
# Processing cluster: TT15/cl-maze1.4
# Number of spikes: 384
# Binned spikes shape: (55545,)
# Processing cluster: TT15/cl-maze1.5
# Number of spikes: 1590
# Binned spikes shape: (55545,)
# Processing cluster: TT15/cl-maze1.6
# Number of spikes: 1509
# Binned spikes shape: (55545,)
# Processing cluster: TT16/cl-maze1.1
# Number of spikes: 1064
# Binned spikes shape: (55545,)
# Processing cluster: TT16/cl-maze1.3
# Number of spikes: 9902
# Binned spikes shape: (55545,)
# Processing cluster: TT3/cl-maze1.1
# Number of spikes: 9365
# Binned spikes shape: (55545,)
# Processing cluster: TT4/cl-maze1.1
# Number of spikes: 288
# Binned spikes shape: (55545,)
# Processing cluster: TT4/cl-maze1.2
# Number of spikes: 5019
# Binned spikes shape: (55545,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 3660
# Binned spikes shape: (55545,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 2723
# Binned spikes shape: (55545,)
# Processing cluster: TT5/cl-maze1.3
# Number of spikes: 1730
# Binned spikes shape: (55545,)
# Processing cluster: TT6/cl-maze1.1
# Number of spikes: 4800
# Binned spikes shape: (55545,)
# Processing cluster: TT6/cl-maze1.2
# Number of spikes: 2391
# Binned spikes shape: (55545,)
# Processing cluster: TT6/cl-maze1.3
# Number of spikes: 1199
# Binned spikes shape: (55545,)
# Processing cluster: TT6/cl-maze1.4
# Number of spikes: 272
# Binned spikes shape: (55545,)
# Processing cluster: TT6/cl-maze1.5
# Number of spikes: 679
# Binned spikes shape: (55545,)
# Number of processed clusters: 26
# all spikes shape 26
# Neural data shape: (55545, 26)
# Neural data shape: (55545, 26)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
# Processing session 17/65
# Rat: 791, Day: 15, Epoch: m1
# Processing cluster: TT1/cl-maze1.1
# Number of spikes: 2876
# Binned spikes shape: (116723,)
# Processing cluster: TT1/cl-maze1.2
# Number of spikes: 9466
# Binned spikes shape: (116723,)
# Processing cluster: TT10/cl-maze1.1
# Number of spikes: 1915
# Binned spikes shape: (116723,)
# Processing cluster: TT10/cl-maze1.2
# Number of spikes: 1309
# Binned spikes shape: (116723,)
# Processing cluster: TT10/cl-maze1.3
# Number of spikes: 4002
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.1
# Number of spikes: 142
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.3
# Number of spikes: 66
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.4
# Number of spikes: 432
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.5
# Number of spikes: 1518
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.6
# Number of spikes: 1536
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.7
# Number of spikes: 1009
# Binned spikes shape: (116723,)
# Processing cluster: TT11/cl-maze1.8
# Number of spikes: 643
# Binned spikes shape: (116723,)
# Processing cluster: TT13/cl-maze1.1
# Number of spikes: 10933
# Binned spikes shape: (116723,)
# Processing cluster: TT13/cl-maze1.2
# Number of spikes: 493
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.1
# Number of spikes: 1119
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.11
# Number of spikes: 494
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.14
# Number of spikes: 2840
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.15
# Number of spikes: 3486
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.3
# Number of spikes: 3644
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.4
# Number of spikes: 55
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.5
# Number of spikes: 52
# Binned spikes shape: (116723,)
# Processing cluster: TT14/cl-maze1.8
# Number of spikes: 226
# Binned spikes shape: (116723,)
# Processing cluster: TT15/cl-maze1.4
# Number of spikes: 498
# Binned spikes shape: (116723,)
# Processing cluster: TT2/cl-maze1.2
# Number of spikes: 12965
# Binned spikes shape: (116723,)
# Processing cluster: TT3/cl-maze1.1
# Number of spikes: 4224
# Binned spikes shape: (116723,)
# Processing cluster: TT3/cl-maze1.2
# Number of spikes: 7223
# Binned spikes shape: (116723,)
# Processing cluster: TT3/cl-maze1.3
# Number of spikes: 532
# Binned spikes shape: (116723,)
# Processing cluster: TT3/cl-maze1.6
# Number of spikes: 478
# Binned spikes shape: (116723,)
# Processing cluster: TT4/cl-maze1.1
# Number of spikes: 1782
# Binned spikes shape: (116723,)
# Processing cluster: TT5/cl-maze1.1
# Number of spikes: 3003
# Binned spikes shape: (116723,)
# Processing cluster: TT5/cl-maze1.2
# Number of spikes: 8162
# Binned spikes shape: (116723,)
# Processing cluster: TT6/cl-maze1.1
# Number of spikes: 848
# Binned spikes shape: (116723,)
# Processing cluster: TT6/cl-maze1.3
# Number of spikes: 152
# Binned spikes shape: (116723,)
# Processing cluster: TT6/cl-maze1.4
# Number of spikes: 378
# Binned spikes shape: (116723,)
# Processing cluster: TT6/cl-maze1.5
# Number of spikes: 731
# Binned spikes shape: (116723,)
# Processing cluster: TT8/cl-maze1.1
# Number of spikes: 61971
# Binned spikes shape: (116723,)
# Number of processed clusters: 36
# all spikes shape 36
# Neural data shape: (116723, 36)
# Neural data shape: (116723, 36)
# Input neural data shape: (1000, 100)
# Output embeddings shape: (1000, 2)
